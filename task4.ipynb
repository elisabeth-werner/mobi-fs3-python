# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/lena.png` and show it:

# %%
img = plt.imread("data/lena.png")
plt.imshow(img, "gray")

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical $3 \times 3$ Prewitt filters:

# %%
def prewitt_h(img):
    result = numpy.zeros(img.shape)
    kernel_h = numpy.array([[-1, 0, 1],
                            [-1, 0, 1],
                            [-1, 0, 1]])
    for p in numpy.ndindex(img.shape):
        if p[0] < 1 or p [1] < 1 or p[0] >= img.shape[0] - 1 or p[1] >= img.shape[1] - 1:
            continue
        neighborhood_sum_weighted = 0
        for q in numpy.ndindex(3,3):
            i, j = p[0] - 1 + q[0], p[1] - 1 + q[1]
            if 0 <= i < img.shape[0] and 0 <= img.shape[1]:
                neighborhood_sum_weighted += img[i,j] * 1/6 * kernel_h[q]
        result[p] = neighborhood_sum_weighted
    return result
    
def prewitt_v(img):
    result = numpy.zeros(img.shape)
    kernel_v = numpy.array([[-1, -1, -1],
                            [0, 0, 0],
                            [1, 1, 1]])
    for p in numpy.ndindex(img.shape):
        if p[0] < 1 or p [1] < 1 or p[0] >= img.shape[0] - 1 or p[1] >= img.shape[1] - 1:
            continue
        neighborhood_sum_weighted = 0
        for q in numpy.ndindex(3,3):
            i, j = p[0] - 1 + q[0], p[1] - 1 + q[1]
            if 0 <= i < img.shape[0] and 0 <= img.shape[1]:
                neighborhood_sum_weighted += img[i,j] * 1/6 * kernel_v[q]
        result[p] = neighborhood_sum_weighted
    return result

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %%
lenaprewitt_h = prewitt_h(img.copy())
plt.imshow(lenaprewitt_h, "gray")
plt.colorbar()

lenaprewitt_v = prewitt_v(img.copy())
plt.imshow(lenaprewitt_v, "gray")
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/lena_prewitt_h.tiff` and `data/lena_prewitt_v.tiff`:

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %%
magnitude_img = numpy.zeros(img.shape)
for p in numpy.ndindex(img.shape):
    magnitude_img[p] = numpy.sqrt(magnitude_img.prewitt_h[p]**2 + magnitude_img.prewitt_v[p]**2)

plt.imshow(magnitude_img)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 3
#       1 magnitude_img = numpy.zeros(img.shape)
#       2 for p in numpy.ndindex(img.shape):
# ----> 3     magnitude_img[p] = numpy.sqrt(magnitude_img.prewitt_h[p]**2 + magnitude_img.prewitt_v[p]**2)
#       5 plt.imshow(magnitude_img)
#       6 plt.colorbar()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'prewitt_h'

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/lena_prewitt_gradmag.tiff`:

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical $3 \times 3$ Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/lena_sobel_h.tiff` and `data/lena_sobel_v.tiff`:
